# %%
import requests
from bs4 import BeautifulSoup as BSoup
import pandas as pd
requests.packages.urllib3.disable_warnings()

# %%
from bs4 import BeautifulSoup as BSoup
import requests
import re
skill_list = []
company_list = []
experience_list = []
skill_list = []
position_list = []

with requests.Session() as s:
    for page in range(1,100):
        headers = {'User-Agent' : 'Mozilla/5.0'}
        url = 'https://www.timesjobs.com/candidate/job-search.html?from=submit&searchType=personalizedSearch&txtLocation=Cochin/%20Kochi/%20Ernakulam&luceneResultSize=25&postWeek=60&pDate=Y&sequence=' + str(page)
#         print(url)
        r = s.get(url, headers = headers)
        soup = BSoup(r.content,'html.parser')
#         print(url)
       
        tables = soup.find_all('li', {"class": "clearfix job-bx wht-shd-bx"})
#         print(tables)
        for table in tables:
           position = table.find('h2').text.split(' ',1)[1]
           company = table.find('h3', {"class": "joblist-comp-name"}).text.split(' ',1)[1].split('\r',1)[0]
           experience = table.find_all('li')[0].text.split('-',1)[1]
           skillset    =  table.find('span', {"class": "srp-skills"}).text.split(' ',1)[1]
           skills  = skillset.split('\n',1)[1]
           position_list.append(position)
           company_list.append(company)
           experience_list.append(experience)
           skill_list.append(skills)

# %%
df=pd.DataFrame()

# %%
df['Job Position']=position_list
df['Company']=company_list
df['Experience']=experience_list
df['Skills']=skill_list
df['City']='Kochi'

# %%
df
# Out:
#                                            Job Position  \
# 0                                  Associate 1  Campus
# 1                  UI / Front end Developer(AngularJS)
# 2                               AWS SOLUTION ARCHITECT
# 3                                       TECHNICAL LEAD
# 4                                   FRONTEND DEVELOPER
# ...                                                 ...
# 1369                                      Farm Manager
# 1370                      Flutter Mobile App Developer
# 1371                         Fullstack - PHP Developer
# 1372       Vacancies Part Time Internet | Limited Ur...
# 1373         SEO Analyst,SEO Specialist,SEO Strategist
#
#                              Company Experience  \
# 0                               kpmg      3 yrs
# 1                   Infocom Software      3 yrs
# 2               mantis hr consulting     12 yrs
# 3               mantis hr consulting      8 yrs
# 4               mantis hr consulting      4 yrs
# ...

# %%
from bs4 import BeautifulSoup as BSoup
import requests
import re
skill_list = []
company_list = []
experience_list = []
skill_list = []
position_list = []
city = 'bangalore'
with requests.Session() as s:
    for page in range(1,100):
        headers = {'User-Agent' : 'Mozilla/5.0'}
        url = 'https://www.timesjobs.com/candidate/job-search.html?from=submit&searchType=personalizedSearch&txtLocation=' + city +'&luceneResultSize=25&postWeek=60&pDate=Y&sequence=' + str(page)
#         print(url)
        r = s.get(url, headers = headers)
        soup = BSoup(r.content,'html.parser')
#         print(url)
       
        tables = soup.find_all('li', {"class": "clearfix job-bx wht-shd-bx"})
#         print(tables)
        for table in tables:
           position = table.find('h2').text.split(' ',1)[1]
           company = table.find('h3', {"class": "joblist-comp-name"}).text.split(' ',1)[1].split('\r',1)[0]
           experience = table.find_all('li')[0].text.split('-',1)[1]
           try:
               skillset    =  table.find('span', {"class": "srp-skills"}).text.split(' ',1)[1]
               skills  = skillset.split('\n',1)[1]
           except:
               skills = ' '
           position_list.append(position)
           company_list.append(company)
           experience_list.append(experience)
           skill_list.append(skills)

# %%
df2=pd.DataFrame()

# %%
df2['Job Position']=position_list
df2['Company']=company_list
df2['Experience']=experience_list
df2['Skills']=skill_list
df2['City']='Banglore'

# %%
df2
# Out:
#                                            Job Position  \
# 0          Backend Developer (NestJS)-Immediate Join...
# 1                                    Software Engineer
# 2                        Credit Risk Analytics Sr Assc
# 3                           Credit Risk Analytics Assc
# 4                                    Software Engineer
# ...                                                 ...
# 2470                    Principal Full stack Developer
# 2471                                  Jio Point Lead C
# 2472          Network Domain SME - Telecom (RAN, ORAN)
# 2473                                  Accountant 2-Fin
# 2474                    Package Consultant: Salesforce
#
#                                      Company Experience  \
# 0                Perfect Publishing Solution      8 yrs
# 1                          WELLS FARGO INDIA     12 yrs
# 2                          WELLS FARGO INDIA      8 yrs
# 3                          WELLS FARGO INDIA      5 yrs
# ...

# %%
from bs4 import BeautifulSoup as BSoup
import requests
import re
skill_list = []
company_list = []
experience_list = []
skill_list = []
position_list = []
city = 'chennai'
with requests.Session() as s:
    for page in range(1,100):
        headers = {'User-Agent' : 'Mozilla/5.0'}
        url = 'https://www.timesjobs.com/candidate/job-search.html?from=submit&searchType=personalizedSearch&txtLocation=' + city +'&luceneResultSize=25&postWeek=60&pDate=Y&sequence=' + str(page)
#         print(url)
        r = s.get(url, headers = headers)
        soup = BSoup(r.content,'html.parser')
#         print(url)
       
        tables = soup.find_all('li', {"class": "clearfix job-bx wht-shd-bx"})
#         print(tables)
        for table in tables:
           position = table.find('h2').text.split(' ',1)[1]
           company = table.find('h3', {"class": "joblist-comp-name"}).text.split(' ',1)[1].split('\r',1)[0]
           experience = table.find_all('li')[0].text.split('-',1)[1]
           try:
               skillset    =  table.find('span', {"class": "srp-skills"}).text.split(' ',1)[1]
               skills  = skillset.split('\n',1)[1]
           except:
               skills = ' '
           position_list.append(position)
           company_list.append(company)
           experience_list.append(experience)
           skill_list.append(skills)

# %%
df3=pd.DataFrame()

# %%
df3['Job Position']=position_list
df3['Company']=company_list
df3['Experience']=experience_list
df3['Skills']=skill_list
df3['City']='Chennai'

# %%
df3
# Out:
#                                            Job Position  \
# 0                                    Software Engineer
# 1                        Credit Risk Analytics Sr Assc
# 2                           Credit Risk Analytics Assc
# 3                                    Software Engineer
# 4                        Credit Risk Analytics Sr Assc
# ...                                                 ...
# 2470       Sales & Marketing Manager,Sales Manager,C...
# 2471       Manager ,Customer Service Representative,...
# 2472                        Online Promotion-Part Time
# 2473                  Chef Chef De Partie/Station Chef
# 2474       Data Entry Operator,Business Analyst,Mana...
#
#                                      Company Experience  \
# 0                          WELLS FARGO INDIA     12 yrs
# 1                          WELLS FARGO INDIA      8 yrs
# 2                          WELLS FARGO INDIA      5 yrs
# 3        Wells Fargo India Solutions Pvt Ltd     12 yrs
# ...

# %%
from bs4 import BeautifulSoup as BSoup
import requests
import re
skill_list = []
company_list = []
experience_list = []
skill_list = []
position_list = []
city = 'hyderabad'
with requests.Session() as s:
    for page in range(1,100):
        headers = {'User-Agent' : 'Mozilla/5.0'}
        url = 'https://www.timesjobs.com/candidate/job-search.html?from=submit&searchType=personalizedSearch&txtLocation=' + city +'&luceneResultSize=25&postWeek=60&pDate=Y&sequence=' + str(page)
#         print(url)
        r = s.get(url, headers = headers)
        soup = BSoup(r.content,'html.parser')
#         print(url)
       
        tables = soup.find_all('li', {"class": "clearfix job-bx wht-shd-bx"})
#         print(tables)
        for table in tables:
           position = table.find('h2').text.split(' ',1)[1]
           company = table.find('h3', {"class": "joblist-comp-name"}).text.split(' ',1)[1].split('\r',1)[0]
           experience = table.find_all('li')[0].text.split('-',1)[1]
           try:
               skillset    =  table.find('span', {"class": "srp-skills"}).text.split(' ',1)[1]
               skills  = skillset.split('\n',1)[1]
           except:
               skills = ' '
           position_list.append(position)
           company_list.append(company)
           experience_list.append(experience)
           skill_list.append(skills)

# %%
df4=pd.DataFrame()

# %%
df4['Job Position']=position_list
df4['Company']=company_list
df4['Experience']=experience_list
df4['Skills']=skill_list
df4['City']='Hyderabad'

# %%
df4
# Out:
#                                   Job Position  \
# 0                           Software Engineer
# 1               Credit Risk Analytics Sr Assc
# 2                  Credit Risk Analytics Assc
# 3                           Software Engineer
# 4               Credit Risk Analytics Sr Assc
# ...                                        ...
# 2470               Advanced Modeling Engineer
# 2471                           Head Logistics
# 2472       Territory Manager Techno Marketing
# 2473                          Legal Executive
# 2474             Network System Administrator
#
#                                      Company Experience  \
# 0                          WELLS FARGO INDIA     12 yrs
# 1                          WELLS FARGO INDIA      8 yrs
# 2                          WELLS FARGO INDIA      5 yrs
# 3        Wells Fargo India Solutions Pvt Ltd     12 yrs
# 4        Wells Fargo India Solutions Pvt Ltd      8 yrs
# ...                                      ...        ...
# ...

# %%
df = df.append([df2,df3,df4])

# %%
df.to_excel("skills.xlsx", index=False)
